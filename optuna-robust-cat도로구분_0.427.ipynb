# %%
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')
from sklearn.preprocessing import LabelEncoder,StandardScaler,MinMaxScaler,RobustScaler
from category_encoders.target_encoder import TargetEncoder

from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error,mean_squared_log_error,make_scorer
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sns
import optuna
from optuna.samplers import TPESampler


import os
from catboost import CatBoostRegressor
from tqdm import tqdm
from sklearn.model_selection import KFold

# %%
train = pd.read_csv("train2.csv").drop(['사망자수','중상자수','경상자수','부상자수'],axis=1)
test = pd.read_csv("test(통합본).csv")

# %%
def gu(address):
    return address.split()[0]
def dong(address):
    return address.split()[1]
def road_1(x):
    return x.split(' - ')[0]
def road_2(x):
    return x.split(' - ')[1]

# %%
for df in [train,test]:
    df['구'] = df['주소'].apply(gu)
    df['동'] = df['주소'].apply(dong)
    df.drop('주소',axis=1,inplace=True)
    df['도로구분1'] = df['도로형태'].apply(road_1)
    df['도로구분2'] = df['도로형태'].apply(road_2)
    df.drop('도로형태',axis=1,inplace=True)

# %%
train = train[['요일', '기상상태', '도로구분1','도로구분2', '노면상태', '사고유형', '구', '동', '연휴', '년도', '월', '일', '시간',
       '설치장소', '설치개수', 'CCTV설치대수', '급지구분_1', '급지구분_2', '급지구분_3', 'ECLO']]
test = test[['요일', '기상상태', '도로구분1','도로구분2', '노면상태', '사고유형', '구', '동', '연휴', '년도', '월', '일', '시간',
       '설치장소', '설치개수', 'CCTV설치대수', '급지구분_1', '급지구분_2', '급지구분_3']]

# %%
categorical_features = list(train.dtypes[train.dtypes == "object"].index)
display(categorical_features)

for i in categorical_features:
    le = LabelEncoder()
    le=le.fit(train[i]) 
    train[i]=le.transform(train[i])
    
    for case in np.unique(test[i]):
        if case not in le.classes_: 
            le.classes_ = np.append(le.classes_, case) 
    test[i]=le.transform(test[i])
# Out:
# ['요일', '기상상태', '도로구분1', '도로구분2', '노면상태', '사고유형', '구', '동']

# %%
train_x = train.drop('ECLO',axis=1)
train_y = np.log(train['ECLO'])
test_x = test

# %%
rs = RobustScaler()
X_standard = rs.fit_transform(train_x)
test_standard = rs.transform(test_x.iloc[:,:])

# %%
X_train, X_valid , y_train , y_valid  = train_test_split(X_standard ,train_y, shuffle=True,test_size=0.2)

# %%
import numpy as np

def rmsle(y_true, y_pred, squared=True):
    assert len(y_true) == len(y_pred), "Input arrays must have the same length."

    y_true_log1p = np.log1p(y_true)
    y_pred_log1p = np.log1p(y_pred)

    if squared:
        return np.mean((y_true_log1p - y_pred_log1p) ** 2)
    else:
        return np.sqrt(np.mean((y_true_log1p - y_pred_log1p) ** 2))

def objective(trial, train_x, train_y, val_x, val_y):
    param = {
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1e-3, 0.1),
        'subsample': trial.suggest_float('subsample', 0.1, 1.0),
        'learning_rate': trial.suggest_float('learning_rate', 0.0001, 0.1),
        'n_estimators': trial.suggest_int('n_estimators', 50, 1000),
        'max_depth': trial.suggest_int('max_depth',4,15),
    }
    model = CatBoostRegressor(**param)
    model.fit(train_x, train_y)
    preds = model.predict(val_x)
    score = rmsle(val_y, preds, squared=False)
    return score

# %%
study =  optuna.create_study(study_name='Catboost', direction='minimize',sampler=TPESampler(seed=42) )
study.optimize(lambda trial: objective(trial,X_train,  y_train ,X_valid , y_valid ),n_trials=50, timeout = 1000 )
print('Best trial:', study.best_trial.params)
print('Best score:', study.best_value)
# 228:	learn: 1.8129483	total: 19.8s	remaining: 33.9s
# 229:	learn: 1.8080269	total: 19.9s	remaining: 33.8s
# 230:	learn: 1.8057139	total: 20s	remaining: 33.7s
# 231:	learn: 1.8024426	total: 20s	remaining: 33.6s
# 232:	learn: 1.7986796	total: 20.1s	remaining: 33.5s
# 233:	learn: 1.7951823	total: 20.2s	remaining: 33.4s
# 234:	learn: 1.7939237	total: 20.3s	remaining: 33.4s
# 235:	learn: 1.7914281	total: 20.4s	remaining: 33.3s
# 236:	learn: 1.7892117	total: 20.5s	remaining: 33.2s
# 237:	learn: 1.7844014	total: 20.6s	remaining: 33.1s
# 238:	learn: 1.7827796	total: 20.7s	remaining: 33s
# 239:	learn: 1.7775946	total: 20.7s	remaining: 32.9s
# 240:	learn: 1.7731284	total: 20.8s	remaining: 32.9s
# 241:	learn: 1.7683987	total: 20.9s	remaining: 32.8s
# 242:	learn: 1.7658450	total: 21s	remaining: 32.7s
# 243:	learn: 1.7630939	total: 21.1s	remaining: 32.6s
# 244:	learn: 1.7605302	total: 21.2s	remaining: 32.5s
# 245:	learn: 1.7563324	total: 21.3s	remaining: 32.4s
# 246:	learn: 1.7542161	total: 21.4s	remaining: 32.3s
# 247:	learn: 1.7527791	total: 21.4s	remaining: 32.3s
# 248:	learn: 1.7475787	total: 21.5s	remaining: 32.2s
# 249:	learn: 1.7444062	total: 21.6s	remaining: 32.1s
# 250:	learn: 1.7396319	total: 21.7s	remaining: 32s
# 251:	learn: 1.7367883	total: 21.8s	remaining: 31.9s
# 252:	learn: 1.7349801	total: 21.9s	remaining: 31.8s
# 253:	learn: 1.7312787	total: 22s	remaining: 31.7s
# 254:	learn: 1.7287170	total: 22.1s	remaining: 31.6s
# 255:	learn: 1.7249968	total: 22.1s	remaining: 31.6s
# 256:	learn: 1.7197280	total: 22.2s	remaining: 31.5s
# 257:	learn: 1.7172384	total: 22.3s	remaining: 31.4s
# 258:	learn: 1.7153814	total: 22.4s	remaining: 31.3s
# 259:	learn: 1.7111979	total: 22.5s	remaining: 31.2s
# 260:	learn: 1.7059836	total: 22.6s	remaining: 31.1s
# 261:	learn: 1.7012635	total: 22.7s	remaining: 31.1s
# 262:	learn: 1.6970809	total: 22.8s	remaining: 31s
# 263:	learn: 1.6939016	total: 22.8s	remaining: 30.9s
# 264:	learn: 1.6902481	total: 22.9s	remaining: 30.8s
# 265:	learn: 1.6889634	total: 23s	remaining: 30.7s
# 266:	learn: 1.6833668	total: 23.1s	remaining: 30.6s
# 267:	learn: 1.6769356	total: 23.2s	remaining: 30.5s
# 268:	learn: 1.6734480	total: 23.3s	remaining: 30.5s
# 269:	learn: 1.6693817	total: 23.4s	remaining: 30.4s
# 270:	learn: 1.6688284	total: 23.4s	remaining: 30.2s
# 271:	learn: 1.6658948	total: 23.5s	remaining: 30.1s
# 272:	learn: 1.6627393	total: 23.6s	remaining: 30s
# 273:	learn: 1.6582548	total: 23.7s	remaining: 30s
# 274:	learn: 1.6556391	total: 23.7s	remaining: 29.9s
# 275:	learn: 1.6512356	total: 23.8s	remaining: 29.8s
# 608:	learn: 3.0947335	total: 3.24s	remaining: 21.3ms
# 609:	learn: 3.0946643	total: 3.25s	remaining: 16ms
# 610:	learn: 3.0946006	total: 3.25s	remaining: 10.6ms
# 611:	learn: 3.0944069	total: 3.26s	remaining: 5.32ms
# 612:	learn: 3.0943528	total: 3.26s	remaining: 0us
# 0:	learn: 3.2300588	total: 7.47ms	remaining: 7.1s
# 1:	learn: 3.2268043	total: 739ms	remaining: 5m 50s
# 2:	learn: 3.2230938	total: 1.42s	remaining: 7m 28s
# 3:	learn: 3.2192746	total: 2.05s	remaining: 8m 5s
# 4:	learn: 3.2171492	total: 2.71s	remaining: 8m 32s
# 5:	learn: 3.2142552	total: 3.35s	remaining: 8m 48s
# 6:	learn: 3.2098653	total: 3.99s	remaining: 8m 58s
# 7:	learn: 3.2072178	total: 4.65s	remaining: 9m 8s
# 8:	learn: 3.2067607	total: 4.66s	remaining: 8m 8s
# 9:	learn: 3.2044381	total: 5.29s	remaining: 8m 18s
# 10:	learn: 3.1995502	total: 5.94s	remaining: 8m 28s
# 11:	learn: 3.1991421	total: 5.95s	remaining: 7m 45s
# 12:	learn: 3.1945168	total: 6.6s	remaining: 7m 56s
# 13:	learn: 3.1914695	total: 7.21s	remaining: 8m 3s
# 14:	learn: 3.1887464	total: 7.86s	remaining: 8m 10s
# 15:	learn: 3.1852873	total: 8.48s	remaining: 8m 16s
# 16:	learn: 3.1813216	total: 9.12s	remaining: 8m 21s
# 17:	learn: 3.1789030	total: 9.74s	remaining: 8m 25s
# 18:	learn: 3.1748268	total: 10.4s	remaining: 8m 30s
# 19:	learn: 3.1710746	total: 11s	remaining: 8m 33s
# 20:	learn: 3.1674378	total: 11.6s	remaining: 8m 35s
# [W 2023-12-09 16:13:26,966] Trial 6 failed with parameters: {'l2_leaf_reg': 0.0611469403382424, 'subsample': 0.2534717113185624, 'learning_rate': 0.006598654139229424, 'n_estimators': 952, 'max_depth': 15} because of the following error: KeyboardInterrupt('').
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Roaming\Python\Python39\site-packages\optuna\study\_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_11772\2668193024.py", line 2, in <lambda>
#     study.optimize(lambda trial: objective(trial,X_train,  y_train ,X_valid , y_valid ),n_trials=50, timeout = 1000 )
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_11772\3867344226.py", line 23, in objective
#     model.fit(train_x, train_y)
#   File "C:\Users\User\AppData\Roaming\Python\Python39\site-packages\catboost\core.py", line 5703, in fit
#     return self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline,
#   File "C:\Users\User\AppData\Roaming\Python\Python39\site-packages\catboost\core.py", line 2319, in _fit
#     self._train(
#   File "C:\Users\User\AppData\Roaming\Python\Python39\site-packages\catboost\core.py", line 1723, in _train
#     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#   File "_catboost.pyx", line 4645, in _catboost._CatBoost._train
#   File "_catboost.pyx", line 4694, in _catboost._CatBoost._train
# KeyboardInterrupt
# [W 2023-12-09 16:13:26,999] Trial 6 failed with value None.
# 21:	learn: 3.1638285	total: 12.3s	remaining: 8m 38s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 2
#       1 study =  optuna.create_study(study_name='Catboost', direction='minimize',sampler=TPESampler(seed=42) )
# ----> 2 study.optimize(lambda trial: objective(trial,X_train,  y_train ,X_valid , y_valid ),n_trials=50, timeout = 1000 )
#       3 print('Best trial:', study.best_trial.params)
#       4 print('Best score:', study.best_value)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\optuna\study\study.py:451, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     348 def optimize(
#     349     self,
#     350     func: ObjectiveFuncType,
#    (...)
#     357     show_progress_bar: bool = False,
#     358 ) -> None:
#     359     """Optimize an objective function.
#     360
#     361     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     449             If nested invocation of this method occurs.
#     450     """
# --> 451     _optimize(
#     452         study=self,
#     453         func=func,
#     454         n_trials=n_trials,
#     455         timeout=timeout,
#     456         n_jobs=n_jobs,
#     457         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     458         callbacks=callbacks,
#     459         gc_after_trial=gc_after_trial,
#     460         show_progress_bar=show_progress_bar,
#     461     )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\optuna\study\_optimize.py:66, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64 try:
#      65     if n_jobs == 1:
# ---> 66         _optimize_sequential(
#      67             study,
#      68             func,
#      69             n_trials,
#      70             timeout,
#      71             catch,
#      72             callbacks,
#      73             gc_after_trial,
#      74             reseed_sampler_rng=False,
#      75             time_start=None,
#      76             progress_bar=progress_bar,
#      77         )
#      78     else:
#      79         if n_jobs == -1:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\optuna\study\_optimize.py:163, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     160         break
#     162 try:
# --> 163     frozen_trial = _run_trial(study, func, catch)
#     164 finally:
#     165     # The following line mitigates memory problems that can be occurred in some
#     166     # environments (e.g., services that use computing containers such as GitHub Actions).
#     167     # Please refer to the following PR for further details:
#     168     # https://github.com/optuna/optuna/pull/325.
#     169     if gc_after_trial:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\optuna\study\_optimize.py:251, in _run_trial(study, func, catch)
#     244         assert False, "Should not reach."
#     246 if (
#     247     frozen_trial.state == TrialState.FAIL
#     248     and func_err is not None
#     249     and not isinstance(func_err, catch)
#     250 ):
# --> 251     raise func_err
#     252 return frozen_trial
#
# File ~\AppData\Roaming\Python\Python39\site-packages\optuna\study\_optimize.py:200, in _run_trial(study, func, catch)
#     198 with get_heartbeat_thread(trial._trial_id, study._storage):
#     199     try:
# --> 200         value_or_values = func(trial)
#     201     except exceptions.TrialPruned as e:
#     202         # TODO(mamu): Handle multi-objective cases.
#     203         state = TrialState.PRUNED
#
# Cell In[35], line 2, in <lambda>(trial)
#       1 study =  optuna.create_study(study_name='Catboost', direction='minimize',sampler=TPESampler(seed=42) )
# ----> 2 study.optimize(lambda trial: objective(trial,X_train,  y_train ,X_valid , y_valid ),n_trials=50, timeout = 1000 )
#       3 print('Best trial:', study.best_trial.params)
#       4 print('Best score:', study.best_value)
#
# Cell In[34], line 23, in objective(trial, train_x, train_y, val_x, val_y)
#      15 param = {
#      16     'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1e-3, 0.1),
#      17     'subsample': trial.suggest_float('subsample', 0.1, 1.0),
#    (...)
#      20     'max_depth': trial.suggest_int('max_depth',4,15),
#      21 }
#      22 model = CatBoostRegressor(**param)
# ---> 23 model.fit(train_x, train_y)
#      24 preds = model.predict(val_x)
#      25 score = rmsle(val_y, preds, squared=False)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\catboost\core.py:5703, in CatBoostRegressor.fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    5700 if 'loss_function' in params:
#    5701     CatBoostRegressor._check_is_compatible_loss(params['loss_function'])
# -> 5703 return self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline,
#    5704                  use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description,
#    5705                  verbose_eval, metric_period, silent, early_stopping_rounds,
#    5706                  save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\catboost\core.py:2319, in CatBoost._fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, plot_file, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2315 allow_clear_pool = train_params["allow_clear_pool"]
#    2317 with log_fixup(log_cout, log_cerr), \
#    2318     plot_wrapper(plot, plot_file, 'Training plots', [_get_train_dir(self.get_params())]):
# -> 2319     self._train(
#    2320         train_pool,
#    2321         train_params["eval_sets"],
#    2322         params,
#    2323         allow_clear_pool,
#    2324         train_params["init_model"]
#    2325     )
#    2327 # Have property feature_importance possibly set
#    2328 loss = self._object._get_loss_function_name()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\catboost\core.py:1723, in _CatBoostBase._train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1722 def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1723     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1724     self._set_trained_model_attributes()
#
# File _catboost.pyx:4645, in _catboost._CatBoost._train()
#
# File _catboost.pyx:4694, in _catboost._CatBoost._train()
#
# KeyboardInterrupt:

# %%
model_cat = CatBoostRegressor(**study.best_trial.params)
kf = KFold(n_splits=5, shuffle=True , random_state=42)

ensemble_predicts= []
scores =[]


for train_idx, val_idx in tqdm(kf.split(X_standard), total=5, desc="Processing folds"):
    X_t, X_val = X_standard[train_idx], X_standard[val_idx]
    y_t, y_val = train_y[train_idx], train_y[val_idx]
    
    # 두 모델 모두 학습
    model_cat.fit(X_t, y_t)
    
    # 각 모델로부터 Validation set에 대한 예측을 평균내어 앙상블 예측 생성
    val_pred = model_cat.predict(X_val)
    
    # Validation set에 대한 대회 평가 산식 계산 후 저장
    scores.append(rmsle(y_val, val_pred))
    
    # test 데이터셋에 대한 예측 수행 후 저장
    model_cat_pred = np.exp(model_cat.predict(test_standard))
    model_cat_pred = np.where(model_cat_pred < 0, 0, model_cat_pred)
    
    ensemble_predicts.append(model_cat_pred)

# K-fold 모든 예측의 평균을 계산하여 fold별 모델들의 앙상블 예측 생성
final_predictions = np.mean(ensemble_predicts, axis=0)

# 각 fold에서의 Validation Metric Score와 전체 평균 Validation Metric Score출력
print("Validation : RMSLE scores for each fold:", scores)
print("Validation : RMSLE:", np.mean(scores))

# %%
final_predictions
# Out:
# array([3.84142443, 3.44403305, 5.15275654, ..., 4.3555348 , 4.17960141,
#        4.71029388])

# %%
submission = pd.read_csv('C:/Users/User/Desktop/대구교통사고예측/sample_submission.csv')
submission['ECLO'] = final_predictions
submission.to_csv('C:/Users/User/Desktop/대구교통사고예측/optuna_cat2.csv',index=False)
submission
# Out:
#                    ID      ECLO
# 0      ACCIDENT_39609  3.841424
# 1      ACCIDENT_39610  3.444033
# 2      ACCIDENT_39611  5.152757
# 3      ACCIDENT_39612  4.068527
# 4      ACCIDENT_39613  4.952406
# ...               ...       ...
# 10958  ACCIDENT_50567  4.605680
# 10959  ACCIDENT_50568  4.218216
# 10960  ACCIDENT_50569  4.355535
# 10961  ACCIDENT_50570  4.179601
# 10962  ACCIDENT_50571  4.710294
#
# [10963 rows x 2 columns]

# %%
min(final_predictions),max(final_predictions),np.mean(final_predictions)
# Out:
# (2.0027562345033463, 5.996977754134176, 3.9406467058559342)

# %%
p = pd.read_csv('C:/Users/User/Desktop/대구교통사고예측/cat_pred_0.4269.csv')

# %%
p
# Out:
#                    ID      ECLO
# 0      ACCIDENT_39609  3.861853
# 1      ACCIDENT_39610  3.451107
# 2      ACCIDENT_39611  5.133610
# 3      ACCIDENT_39612  4.464113
# 4      ACCIDENT_39613  4.625894
# ...               ...       ...
# 10958  ACCIDENT_50567  4.242687
# 10959  ACCIDENT_50568  4.097948
# 10960  ACCIDENT_50569  4.295058
# 10961  ACCIDENT_50570  4.184488
# 10962  ACCIDENT_50571  4.416759
#
# [10963 rows x 2 columns]

# %%
min(p['ECLO']),max(p['ECLO']),np.mean(p['ECLO'])
# Out:
# (2.500139643718016, 5.888244422157497, 4.051512172002897)

# %%
xg = pd.read_csv('C:/Users/User/Desktop/대구교통사고예측/optuna_xgb2.csv')
xg
# Out:
#                    ID      ECLO
# 0      ACCIDENT_39609  3.367258
# 1      ACCIDENT_39610  3.224864
# 2      ACCIDENT_39611  4.509228
# 3      ACCIDENT_39612  3.952304
# 4      ACCIDENT_39613  3.980799
# ...               ...       ...
# 10958  ACCIDENT_50567  3.866031
# 10959  ACCIDENT_50568  3.967485
# 10960  ACCIDENT_50569  4.005776
# 10961  ACCIDENT_50570  3.986940
# 10962  ACCIDENT_50571  4.021140
#
# [10963 rows x 2 columns]

# %%
min(xg['ECLO']),max(xg['ECLO']),np.mean(xg['ECLO'])
# Out:
# (2.4403484, 4.7770643, 3.6671455118945544)

# %%
fin = []
for a,b in zip(final_predictions,xg['ECLO']):
    fin.append((a+b)/2)

# %%
submission = pd.read_csv('C:/Users/User/Desktop/대구교통사고예측/sample_submission.csv')
submission['ECLO'] = fin
submission.to_csv('C:/Users/User/Desktop/대구교통사고예측/optuna_cat2andxgb2.csv',index=False)
submission
# Out:
#                    ID      ECLO
# 0      ACCIDENT_39609  3.604341
# 1      ACCIDENT_39610  3.334449
# 2      ACCIDENT_39611  4.830992
# 3      ACCIDENT_39612  4.010415
# 4      ACCIDENT_39613  4.466603
# ...               ...       ...
# 10958  ACCIDENT_50567  4.235856
# 10959  ACCIDENT_50568  4.092851
# 10960  ACCIDENT_50569  4.180655
# 10961  ACCIDENT_50570  4.083271
# 10962  ACCIDENT_50571  4.365717
#
# [10963 rows x 2 columns]
